# %% [markdown]
# # Data cleaning

# %% [markdown]
# We found this .csv file in Kaggle which may be exactly what we need for this project. We are going to go through it, understand the data and clean what we don't need for the analysis.
#
# The .csv file will be on the same GitHub repository.

# %%
import pandas as pd

df = pd.read_csv("./true_cost_fast_fashion.csv")
df.head()
# Out:
#         Brand    Country  Year  Monthly_Production_Tonnes  Avg_Item_Price_USD  \
# 0       Shein  Indonesia  2017                     574.51               19.31
# 1  Forever 21    Vietnam  2024                     394.50                9.30
# 2      Uniqlo      India  2024                     310.23               25.46
# 3  Forever 21        USA  2017                     218.65               13.17
# 4        Zara  Indonesia  2016                    1005.84               15.40
#
#    Release_Cycles_Per_Year  Carbon_Emissions_tCO2e  \
# 0                       16                11421.58
# 1                       20                 5571.01
# 2                       11                10969.00
# 3                       13                13093.00
# 4                       20                 9548.40
#
#    Water_Usage_Million_Litres  Landfill_Waste_Tonnes  Avg_Worker_Wage_USD  \
# 0                      282.11                 616.63               143.79
# ...

# %%
print(df.shape)
print("\n")
print(df.info())
print("\n")
print(df.isna().sum())
print("\n")
print("Nº of duplicates: ", df.duplicated().sum())
print("\n")
# Out:
# (3000, 25)
#
#
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Brand                         3000 non-null   str
#  1   Country                       3000 non-null   str
#  2   Year                          3000 non-null   int64
#  3   Monthly_Production_Tonnes     3000 non-null   float64
#  4   Avg_Item_Price_USD            3000 non-null   float64
#  5   Release_Cycles_Per_Year       3000 non-null   int64
#  6   Carbon_Emissions_tCO2e        3000 non-null   float64
#  7   Water_Usage_Million_Litres    3000 non-null   float64
#  8   Landfill_Waste_Tonnes         3000 non-null   float64
#  9   Avg_Worker_Wage_USD           3000 non-null   float64
#  10  Working_Hours_Per_Week        3000 non-null   int64
#  11  Child_Labor_Incidents         3000 non-null   int64
# ...

# %% [markdown]
# The dataset looks super clean and ready for analysis. There are no duplicates, no null values, columns are properly named and the data types for each columns seem to be the appropiated one.
#
# We want to focus our analysis on three brands: Zara, Shein and H&M.

# %%
df["Brand"].value_counts()
# Out:
# Brand
# H&M           650
# Forever 21    617
# Zara          606
# Uniqlo        581
# Shein         546
# Name: count, dtype: int64

# %%
filtered_df = df[df["Brand"].isin(["Shein", "H&M", "Zara"])]
filtered_df = filtered_df.reset_index()
filtered_df = filtered_df.drop(columns = ["index"])
filtered_df.head()
# Out:
#    Brand    Country  Year  Monthly_Production_Tonnes  Avg_Item_Price_USD  \
# 0  Shein  Indonesia  2017                     574.51               19.31
# 1   Zara  Indonesia  2016                    1005.84               15.40
# 2    H&M  Indonesia  2017                     408.45               18.42
# 3    H&M     Turkey  2021                     467.85               16.55
# 4    H&M    Vietnam  2023                     382.51               18.39
#
#    Release_Cycles_Per_Year  Carbon_Emissions_tCO2e  \
# 0                       16                11421.58
# 1                       20                 9548.40
# 2                       17                14115.59
# 3                       22                 7594.52
# 4                       28                15616.96
#
#    Water_Usage_Million_Litres  Landfill_Waste_Tonnes  Avg_Worker_Wage_USD  \
# 0                      282.11                 616.63               143.79
# ...

# %%
filtered_df.shape
# Out:
# (1802, 25)

# %% [markdown]
# Now, we want to filter columns (we could have done it before filtering by brand, but it won't change our output).

# %%
filtered_df.columns
# Out:
# Index(['Brand', 'Country', 'Year', 'Monthly_Production_Tonnes',
#        'Avg_Item_Price_USD', 'Release_Cycles_Per_Year',
#        'Carbon_Emissions_tCO2e', 'Water_Usage_Million_Litres',
#        'Landfill_Waste_Tonnes', 'Avg_Worker_Wage_USD',
#        'Working_Hours_Per_Week', 'Child_Labor_Incidents',
#        'Return_Rate_Percent', 'Avg_Spend_Per_Customer_USD',
#        'Shopping_Frequency_Per_Year', 'Instagram_Mentions_Thousands',
#        'TikTok_Mentions_Thousands', 'Sentiment_Score',
#        'Social_Sentiment_Label', 'GDP_Contribution_Million_USD',
#        'Env_Cost_Index', 'Sustainability_Score', 'Transparency_Index',
#        'Compliance_Score', 'Ethical_Rating'],
#       dtype='str')

# %%
filtered_df = filtered_df.drop(columns = ['Avg_Item_Price_USD', 'Avg_Worker_Wage_USD',
       'Working_Hours_Per_Week', 'Child_Labor_Incidents',
       'Return_Rate_Percent', 'Avg_Spend_Per_Customer_USD',
       'Shopping_Frequency_Per_Year',
       'Social_Sentiment_Label'])
filtered_df.head()
# Out:
#    Brand    Country  Year  Monthly_Production_Tonnes  Release_Cycles_Per_Year  \
# 0  Shein  Indonesia  2017                     574.51                       16
# 1   Zara  Indonesia  2016                    1005.84                       20
# 2    H&M  Indonesia  2017                     408.45                       17
# 3    H&M     Turkey  2021                     467.85                       22
# 4    H&M    Vietnam  2023                     382.51                       28
#
#    Carbon_Emissions_tCO2e  Water_Usage_Million_Litres  Landfill_Waste_Tonnes  \
# 0                11421.58                      282.11                 616.63
# 1                 9548.40                      142.07                 830.10
# 2                14115.59                      210.53                 738.14
# 3                 7594.52                      283.04                1081.04
# 4                15616.96                      223.78                 674.88
#
# ...

# %%
filtered_df.shape
# Out:
# (1802, 17)

# %% [markdown]
# After filtering columns and brands. We are creating new DFs for each of our chosen brands.

# %%
zara_df = filtered_df.groupby("Brand").get_group("Zara")
shein_df = filtered_df.groupby("Brand").get_group("Shein")
hm_df = filtered_df.groupby("Brand").get_group("H&M")

# %% [markdown]
# We need to apply the same sorting and calculations for the three of them, so we used the following functions to perform easily the same process to them.

# %%
def sort_df(df):
    """
    It takes a df. It sorts them by Country and Year and, then, set a multiindex with Brand, Country and Year
    """
    sorted_df = df.sort_values(["Country", "Year"]).set_index(["Brand", "Country", "Year"])
    
    return sorted_df
    
def merging_years(df):
    """
    It takes a DataFrame, groups the dataframe by brand, country and year, 
    makes different operations depending on the column and returns the DataFrame with the resulting data
    """
    
    merged_df = round (df.groupby(["Brand", "Country", "Year"]).agg({
    'Monthly_Production_Tonnes' : "sum", 
    'Release_Cycles_Per_Year' : "sum",
    'Carbon_Emissions_tCO2e' : "sum", 
    'Water_Usage_Million_Litres' : "sum",
    'Landfill_Waste_Tonnes' : "sum", 
    'Instagram_Mentions_Thousands' : "sum",
    'TikTok_Mentions_Thousands' : "sum", 
    'Sentiment_Score' : "mean",
    'GDP_Contribution_Million_USD' : "sum", 
    'Env_Cost_Index' : "mean",
    'Sustainability_Score' : "mean", 
    'Transparency_Index' : "mean",
    'Compliance_Score' : "mean",
    'Ethical_Rating' : "mean"
    }), 2)
    
    return merged_df

def social_media_sum(df):
    """
    It takes a DataFrame and adds columns standing for social media mentions. 
    It creates a new column with the total and removes the TikTok and Instagram ones 
    """

    df["Social_Media_Mentions_Thousands"] = df["TikTok_Mentions_Thousands"] + df ["Instagram_Mentions_Thousands"]
    df.drop(columns = ["TikTok_Mentions_Thousands", "Instagram_Mentions_Thousands"])
    
    return df
    
def label_system(x):
    """
    It takes a number and generates a label based on it.
    """
    
    if x >= 0.5 and x <=1:
        return "Very positive"
    if x >= 0.1 and x < 0.5:
         return "Positive"
    if x >= -0.1 and x < 0.1:
        return "Neutral"
    if x >= -0.5 and x < -0.1:
        return "Negative"
    if x >= -1 and x < -0.5:
        return "Very negative"

def sentiment_score_label(df):
    """
    It takes a DataFrame. Based on the Sentiment_Score column it adds a label to a new column.
    """
   
    df["Sentiment_Score_Label"] = df["Sentiment_Score"].apply(label_system)

    return df

def sort_columns(df):
    """
    It takes a DataFrame and sort its columns.
    """
    
    df = df[['Monthly_Production_Tonnes', 'Release_Cycles_Per_Year', 'GDP_Contribution_Million_USD',
        'Carbon_Emissions_tCO2e', 'Water_Usage_Million_Litres', 'Landfill_Waste_Tonnes', 
        'Social_Media_Mentions_Thousands', 'Sentiment_Score', 'Sentiment_Score_Label', 
        'Env_Cost_Index', 'Sustainability_Score', 'Transparency_Index', 'Compliance_Score', 'Ethical_Rating']]
    
    return df

# %%
zara_df = sort_df(zara_df)
zara_df = merging_years(zara_df)
zara_df = social_media_sum(zara_df)
zara_df = sentiment_score_label(zara_df)
zara_df = sort_columns(zara_df)
zara_df
# Out:
#                        Monthly_Production_Tonnes  Release_Cycles_Per_Year  \
# Brand Country    Year
# Zara  Bangladesh 2015                    2542.62                       92
#                  2016                    3109.76                      109
#                  2017                    2747.33                      103
#                  2018                    2173.42                       61
#                  2019                    2096.70                      120
# ...                                          ...                      ...
#       Vietnam    2020                    3048.27                      116
#                  2021                    3525.74                      104
#                  2022                    1372.93                       37
#                  2023                    1729.30                       77
#                  2024                    3006.00                      105
#
# ...

# %%
shein_df = sort_df(shein_df)
shein_df = merging_years(shein_df)
shein_df = social_media_sum(shein_df)
shein_df = sentiment_score_label(shein_df)
shein_df = sort_columns(shein_df)
shein_df
# Out:
#                        Monthly_Production_Tonnes  Release_Cycles_Per_Year  \
# Brand Country    Year
# Shein Bangladesh 2015                    2527.42                      115
#                  2016                     883.47                       41
#                  2017                    4513.73                      175
#                  2018                    3107.23                       99
#                  2019                    2568.47                      104
# ...                                          ...                      ...
#       Vietnam    2020                    1057.76                       40
#                  2021                    1598.24                       26
#                  2022                    1628.12                       74
#                  2023                    1330.20                       56
#                  2024                    3362.62                      136
#
# ...

# %%
hm_df = sort_df(hm_df)
hm_df = merging_years(hm_df)
hm_df = social_media_sum(hm_df)
hm_df = sentiment_score_label(hm_df)
hm_df = sort_columns(hm_df)
hm_df
# Out:
#                        Monthly_Production_Tonnes  Release_Cycles_Per_Year  \
# Brand Country    Year
# H&M   Bangladesh 2015                    1203.34                       42
#                  2016                    4563.64                      123
#                  2017                    3845.27                      104
#                  2018                    1565.27                       71
#                  2019                    2516.84                       58
# ...                                          ...                      ...
#       Vietnam    2020                    4646.19                      178
#                  2021                    3889.05                      136
#                  2022                    4734.29                      158
#                  2023                    4513.90                      189
#                  2024                    3658.64                      138
#
# ...

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Hypothesis 1

# %% [markdown]
# Once, we have the three datasets well structured and cleaned, we can start making some EDA (Exploratory Data Analysis), which will give us some insights relevant to our hypothesis.
#
# For the first hypotheses, we'll need to take the total amount of carbon emissions per year in the world coming from each one of the brands.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")

# %%
def h1(df):
    """
    It takes a DataFrame, groups it by year and perform operations on specific columns.
    Named h1 after hypothesis 1. 
    """
    df = df.groupby("Year").agg({'Monthly_Production_Tonnes' : "sum",
                             'Release_Cycles_Per_Year' : "sum",
                             'Carbon_Emissions_tCO2e' : "sum", 
                             'Water_Usage_Million_Litres' : "sum",
                             'Landfill_Waste_Tonnes' : "sum", 
                             'GDP_Contribution_Million_USD' : "sum"})
    
    return df

# %%
zara_h1 = h1(zara_df)
shein_h1 = h1(shein_df)
hm_h1 = h1(hm_df)

# %%
zara_h1

# just as an example to see how they look. I'm not printing all of them.
# Out:
#       Monthly_Production_Tonnes  Release_Cycles_Per_Year  \
# Year
# 2015                   32496.07                     1163
# 2016                   30639.46                     1164
# 2017                   34793.44                     1276
# 2018                   25182.75                      892
# 2019                   26994.83                      964
# 2020                   28275.40                     1019
# 2021                   32826.42                     1082
# 2022                   32279.71                     1132
# 2023                   30574.23                     1026
# 2024                   27401.64                     1011
#
#       Carbon_Emissions_tCO2e  Water_Usage_Million_Litres  \
# Year
# 2015               614539.42                    13042.53
# 2016               625524.86                    12514.85
# 2017               720975.50                    14081.52
# 2018               500575.69                    10473.29
# ...

# %% [markdown]
# Firstly, we tried doing barplots. In the end, we come to the conclusion that it wouldn't be the best option to explain what we wanted to explain. We leave here the process as it can be interesting having them. We may even change our minds.

# %%
sns.barplot(data = zara_h1, x="Year", y="Monthly_Production_Tonnes")
plt.title("Zara's monthly production by year")  
plt.xlabel("Year") 
plt.ylabel("Monthly_Production_Tonnes")
plt.show()

sns.barplot(data = zara_h1, x="Year", y="Release_Cycles_Per_Year")
plt.title("Zara's release cycles per year by year")  
plt.xlabel("Year") 
plt.ylabel("Release_Cycles_Per_Year")
plt.show()

sns.barplot(data = zara_h1, x="Year", y="Carbon_Emissions_tCO2e")
plt.title("Zara's Carbon Emissions by year")  
plt.xlabel("Year") 
plt.ylabel("Carbon_Emissions_tCO2e")
plt.show()

sns.barplot(data = zara_h1, x="Year", y="Water_Usage_Million_Litres")
plt.title("Zara's water usage by year")  
plt.xlabel("Year") 
plt.ylabel("Water_Usage_Million_Litres")
plt.show()

sns.barplot(data = zara_h1, x="Year", y="Landfill_Waste_Tonnes")
plt.title("Zara's landfill waste by year")  
plt.xlabel("Year") 
plt.ylabel("Landfill_Waste_Tonnes")
plt.show()

sns.barplot(data = zara_h1, x="Year", y="GDP_Contribution_Million_USD")
plt.title("Zara's GDP contribution by year")  
plt.xlabel("Year") 
plt.ylabel("GDP_Contribution_Million_USD")
plt.show()

# %%
sns.barplot(data = shein_h1, x="Year", y="Monthly_Production_Tonnes")
plt.title("Shein's monthly production by year")  
plt.xlabel("Year") 
plt.ylabel("Monthly_Production_Tonnes")
plt.show()

sns.barplot(data = shein_h1, x="Year", y="Release_Cycles_Per_Year")
plt.title("Shein's release cycles per year by year")  
plt.xlabel("Year") 
plt.ylabel("Release_Cycles_Per_Year")
plt.show()

sns.barplot(data = shein_h1, x="Year", y="Carbon_Emissions_tCO2e")
plt.title("Shein's Carbon Emissions by year")  
plt.xlabel("Year") 
plt.ylabel("Carbon_Emissions_tCO2e")
plt.show()

sns.barplot(data = shein_h1, x="Year", y="Water_Usage_Million_Litres")
plt.title("Shein's water usage by year")  
plt.xlabel("Year") 
plt.ylabel("Water_Usage_Million_Litres")
plt.show()

sns.barplot(data = shein_h1, x="Year", y="Landfill_Waste_Tonnes")
plt.title("Shein's landfill waste by year")  
plt.xlabel("Year") 
plt.ylabel("Landfill_Waste_Tonnes")
plt.show()

sns.barplot(data = shein_h1, x="Year", y="GDP_Contribution_Million_USD")
plt.title("Shein's GDP contribution by year")  
plt.xlabel("Year") 
plt.ylabel("GDP_Contribution_Million_USD")
plt.show()

# %%
sns.barplot(data = hm_h1, x="Year", y="Monthly_Production_Tonnes")
plt.title("H&M's monthly production by year")  
plt.xlabel("Year") 
plt.ylabel("Monthly_Production_Tonnes")
plt.show()

sns.barplot(data = hm_h1, x="Year", y="Release_Cycles_Per_Year")
plt.title("H&M's release cycles per year by year")  
plt.xlabel("Year") 
plt.ylabel("Release_Cycles_Per_Year")
plt.show()

sns.barplot(data = hm_h1, x="Year", y="Carbon_Emissions_tCO2e")
plt.title("H&M's Carbon Emissions by year")  
plt.xlabel("Year") 
plt.ylabel("Carbon_Emissions_tCO2e")
plt.show()

sns.barplot(data = hm_h1, x="Year", y="Water_Usage_Million_Litres")
plt.title("H&M's water usage by year")  
plt.xlabel("Year") 
plt.ylabel("Water_Usage_Million_Litres")
plt.show()

sns.barplot(data = hm_h1, x="Year", y="Landfill_Waste_Tonnes")
plt.title("H&M's landfill waste by year")  
plt.xlabel("Year") 
plt.ylabel("Landfill_Waste_Tonnes")
plt.show()

sns.barplot(data = hm_h1, x="Year", y="GDP_Contribution_Million_USD")
plt.title("H&M's GDP contribution by year")  
plt.xlabel("Year") 
plt.ylabel("GDP_Contribution_Million_USD")
plt.show()

# %% [markdown]
# In the end, what we decided to improve this hypothesis's visualizations was to mix in each visualization the data for each brand and changing the graphic type to a line plot. We think now the visualizations are easier to interpret.

# %%
palette = sns.color_palette("Set2")

plt.figure(figsize=(12, 6))
plt.plot(hm_h1.index, hm_h1["Monthly_Production_Tonnes"], color = palette[0])
plt.plot(shein_h1.index, shein_h1["Monthly_Production_Tonnes"], color = palette[1]) 
plt.plot(zara_h1.index, zara_h1["Monthly_Production_Tonnes"], color = palette[2])

plt.title("H&M, Shein and Zara production") 
plt.xlabel("Year")
plt.ylabel("Monthly_Production_Tonnes")
plt.legend(["H&M", "Shein", "Zara"], bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(hm_h1.index, hm_h1["Carbon_Emissions_tCO2e"], color = palette[0]) 
plt.plot(shein_h1.index, shein_h1["Carbon_Emissions_tCO2e"], color = palette[1]) 
plt.plot(zara_h1.index, zara_h1["Carbon_Emissions_tCO2e"], color = palette[2])

plt.title("H&M, Shein and Zara Carbon Emissions") 
plt.xlabel("Year")
plt.ylabel("Carbon_Emissions_tCO2e")
plt.legend(["H&M", "Shein", "Zara"], bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(hm_h1.index, hm_h1["Water_Usage_Million_Litres"], color = palette[0]) 
plt.plot(shein_h1.index, shein_h1["Water_Usage_Million_Litres"], color = palette[1])
plt.plot(zara_h1.index, zara_h1["Water_Usage_Million_Litres"], color = palette[2])

plt.title("H&M, Shein and Zara Water Usage")
plt.xlabel("Year")
plt.ylabel("Water_Usage_Million_Litres")
plt.legend(["H&M", "Shein", "Zara"], bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()


plt.figure(figsize=(12, 6))
plt.plot(hm_h1.index, hm_h1["Landfill_Waste_Tonnes"], color = palette[0]) 
plt.plot(shein_h1.index, shein_h1["Landfill_Waste_Tonnes"], color = palette[1]) 
plt.plot(zara_h1.index, zara_h1["Landfill_Waste_Tonnes"], color = palette[2])

plt.title("H&M, Shein and Zara landfill waste")
plt.xlabel("Year")
plt.ylabel("Landfill_Waste_Tonnes")
plt.legend(["H&M", "Shein", "Zara"], bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()


plt.figure(figsize=(12, 6))
plt.plot(hm_h1.index, hm_h1["GDP_Contribution_Million_USD"], color = palette[0]) 
plt.plot(shein_h1.index, shein_h1["GDP_Contribution_Million_USD"], color = palette[1]) 
plt.plot(zara_h1.index, zara_h1["GDP_Contribution_Million_USD"], color = palette[2])

plt.title("H&M, Shein and Zara GDP contribution")
plt.xlabel("Year")
plt.ylabel("GDP_Contribution_Million_USD")
plt.legend(["H&M", "Shein", "Zara"], bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# ## Hypothesis 2

# %% [markdown]
# For the second hypothesis, we'll need to group the DataFrames by country instead of by year. Then, we'll just use three columns:
# - Carbon Emissions
# - Water Usage
# - Landfill Waste

# %% [markdown]
# With the second hypothesis we had the same problem: we did the bar plots graphs, but we weren't conviced about the result. They were individual plots and we realised it was better to have all the data together in one. We'll leave the process of getting them just in case.

# %%
def h2(df):
    """
    It takes a DataFrame, groups it by country and perform operations on the three needed columns.
    Named h2 after hypothesis 2. 
    """
    
    df = round(df.groupby("Country").agg({
        'Carbon_Emissions_tCO2e' : "sum", 
        'Water_Usage_Million_Litres' : "sum",
        'Landfill_Waste_Tonnes' : "sum", 
        }), 2)
    
    return df

# %%
zara_h2 = h2(zara_df)
shein_h2 = h2(shein_df)
hm_h2 = h2(hm_df)

# %%
zara_h2
# Out:
#             Carbon_Emissions_tCO2e  Water_Usage_Million_Litres  \
# Country
# Bangladesh               528326.66                    10830.24
# Brazil                   730074.01                    13939.23
# China                    531834.58                    10919.54
# Germany                  548903.49                    11832.02
# India                    620975.85                    12992.18
# Indonesia                649946.26                    12458.14
# Turkey                   630670.15                    13944.98
# UK                       652282.58                    13198.76
# USA                      595475.58                    11727.11
# Vietnam                  538594.29                    10607.01
#
#             Landfill_Waste_Tonnes
# Country
# Bangladesh               41771.00
# Brazil                   52475.71
# China                    42407.40
# Germany                  45914.96
# India                    55583.15
# Indonesia                49806.60
# ...

# %%
plt.figure(figsize=(12, 6))
plt.bar(zara_h2.index, zara_h2["Carbon_Emissions_tCO2e"]) 
plt.title("Zara's Carbon Emissions from 2015 to 2024 by country") 
plt.xlabel("Country")  
plt.ylabel("Carbon_Emissions_tCO2e") 
plt.show()  

plt.figure(figsize=(12, 6))
plt.bar(zara_h2.index, zara_h2["Water_Usage_Million_Litres"]) 
plt.title("Zara's water usage from 2015 to 2024 by country")  
plt.xlabel("Country") 
plt.ylabel("Water_Usage_Million_Litres")
plt.show()

plt.figure(figsize=(12, 6))
plt.bar(zara_h2.index, zara_h2["Landfill_Waste_Tonnes"]) 
plt.title("Zara's landfill waste from 2015 to 2024 by country")  
plt.xlabel("Country")  
plt.ylabel("Landfill_Waste_Tonnes") 
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.bar(shein_h2.index, shein_h2["Carbon_Emissions_tCO2e"])
plt.title("Shein's Carbon Emissions from 2015 to 2024 by country")
plt.xlabel("Country")
plt.ylabel("Carbon_Emissions_tCO2e")
plt.show()

plt.figure(figsize=(12, 6))
plt.bar(shein_h2.index, shein_h2["Water_Usage_Million_Litres"])
plt.title("Shein's water usage from 2015 to 2024 by country")
plt.xlabel("Country")
plt.ylabel("Water_Usage_Million_Litres")
plt.show()

plt.figure(figsize=(12, 6))
plt.bar(shein_h2.index, shein_h2["Landfill_Waste_Tonnes"])
plt.title("Shein's landfill waste from 2015 to 2024 by country")
plt.xlabel("Country")
plt.ylabel("Landfill_Waste_Tonnes")
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.bar(hm_h2.index, hm_h2["Carbon_Emissions_tCO2e"])  
plt.title("H&M's Carbon Emissions from 2015 to 2024 by country")  
plt.xlabel("Country") 
plt.ylabel("Carbon_Emissions_tCO2e")
plt.show()

plt.figure(figsize=(12, 6))
plt.bar(hm_h2.index, hm_h2["Water_Usage_Million_Litres"])
plt.title("H&M's water usage from 2015 to 2024 by country")
plt.xlabel("Country")
plt.ylabel("Water_Usage_Million_Litres")
plt.show()

plt.figure(figsize=(12, 6))
plt.bar(hm_h2.index, hm_h2["Landfill_Waste_Tonnes"])
plt.title("H&M's landfill waste from 2015 to 2024 by country")
plt.xlabel("Country")
plt.ylabel("Landfill_Waste_Tonnes")
plt.show()

# %% [markdown]
# We had to create a new dataset from scracth.

# %%
# we are taking filtered_df, which is the df that we cleaned just before making the individual dfs for each brand.

brands_country_df = round(filtered_df.groupby(["Brand", "Country"])
                            .agg({'Carbon_Emissions_tCO2e' : "sum", 
                            'Water_Usage_Million_Litres' : "sum",
                            'Landfill_Waste_Tonnes' : "sum", 
                            }).reset_index(), 2)
brands_country_df

# this is the result we were looking for. We wanted to keep just these 5 columns for our next visualizations.
# we are using seaborn, so we needed to keep brand and and country as columns.
# Out:
#     Brand     Country  Carbon_Emissions_tCO2e  Water_Usage_Million_Litres  \
# 0     H&M  Bangladesh               668873.35                    13184.19
# 1     H&M      Brazil               518714.84                    10892.84
# 2     H&M       China               547274.69                    10317.35
# 3     H&M     Germany               610028.11                    12346.86
# 4     H&M       India               662858.17                    12852.27
# 5     H&M   Indonesia               670988.10                    13104.38
# 6     H&M      Turkey               724009.50                    13526.13
# 7     H&M          UK               687310.62                    13566.73
# 8     H&M         USA               698641.02                    13331.06
# 9     H&M     Vietnam               766447.62                    15573.86
# 10  Shein  Bangladesh               600906.48                    11549.71
# 11  Shein      Brazil               466944.76                     9408.83
# ...

# %%
plt.figure(figsize = (12, 6))
sns.barplot(data = brands_country_df, x = "Country", y = "Carbon_Emissions_tCO2e", hue = "Brand", palette = 'Set2')
plt.title("Brands' Carbon Emissions from 2015 to 2024 by country")  
plt.xlabel("Country") 
plt.ylabel("Carbon_Emissions_tCO2e")
plt.legend(bbox_to_anchor=(1.01, 1), loc='upper left')
plt.show()

plt.figure(figsize = (12, 6))
sns.barplot(data = brands_country_df, x = "Country", y = "Water_Usage_Million_Litres", hue = "Brand", palette = 'Set2')
plt.title("Brands' water usage from 2015 to 2024 by country")  
plt.xlabel("Country") 
plt.ylabel("Water_Usage_Million_Litres")
plt.legend(bbox_to_anchor=(1.01, 1), loc='upper left')
plt.show()

plt.figure(figsize = (12, 6))
sns.barplot(data = brands_country_df, x = "Country", y = "Landfill_Waste_Tonnes", hue = "Brand", palette = 'Set2')
plt.title("Brands' landfill waste from 2015 to 2024 by country")  
plt.xlabel("Country") 
plt.ylabel("Landfill_Waste_Tonnes")
plt.legend(bbox_to_anchor=(1.01, 1), loc='upper left')
plt.show()
